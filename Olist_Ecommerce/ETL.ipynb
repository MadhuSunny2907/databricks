-- %%
CREATE OR REPLACE TABLE olist.bronze.olist_customers AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_customers_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_geolocation AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_geolocation_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_orders AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_orders_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_order_items AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_order_items_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_products AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_products_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_sellers AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_sellers_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_order_payments AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_order_payments_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_order_reviews AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/olist_order_reviews_dataset.csv',
                    format => 'csv',
                    header => true);

CREATE OR REPLACE TABLE olist.bronze.olist_ctg_name_trans AS
SELECT * FROM read_files('/Volumes/olist/landing/v_olist/product_category_name_translation.csv',
                    format => 'csv',
                    header => true);

-- %%
select to_date(order_purchase_timestamp),count(*) from olist.bronze.olist_orders group by to_date(order_purchase_timestamp) order by to_date(order_purchase_timestamp);

-- %%
select * from olist.bronze.olist_customers where customer_id='9ef432eb6251297304e76186b10a928d'

-- %%
SELECT * FROM read_files('abfss://olist@dbdestorage.dfs.core.windows.net/order.csv',
                    format => 'csv',
                    header => true);

-- %%
CREATE OR REPLACE TABLE OLIST.default.FLOW_STATUS (
FLOW_CD STRING, LAST_PROC_TMS DATE, NEXT_PROC_TMS DATE)

-- %%
INSERT INTO OLIST.default.FLOW_STATUS (FLOW_CD, LAST_PROC_TMS, NEXT_PROC_TMS) VALUES ('OLIST', to_date('2016-09-03'), to_date('2016-09-04'))

-- %%
UPDATE OLIST.default.FLOW_STATUS SET NEXT_PROC_TMS=to_date('2016-10-04') WHERE FLOW_CD='OLIST';
SELECT * FROM OLIST.default.FLOW_STATUS
