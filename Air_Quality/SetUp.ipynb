# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS air_quality
URL 'abfss://airquality@dbdestorage.dfs.core.windows.net'
WITH (CREDENTIAL `dbdeconn`)

# %%
# %sql
CREATE CATALOG IF NOT EXISTS airquality
MANAGED LOCATION 'abfss://airquality@dbdestorage.dfs.core.windows.net/'

# %%
# %sql
USE CATALOG airquality;
CREATE SCHEMA landing;
CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold;

# %%
# %sql
USE CATALOG airquality;
USE SCHEMA landing;
CREATE EXTERNAL VOLUME IF NOT EXISTS l_airquality
LOCATION 'abfss://airquality@dbdestorage.dfs.core.windows.net/landing/'

# %%
# %fs
ls '/Volumes/airquality/landing/l_airquality/'
